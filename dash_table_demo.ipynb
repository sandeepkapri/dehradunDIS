# %%
import dash
import dash_table
import pandas as pd
import dash_bootstrap_components as dbc
import dash_html_components as html
from dash.dependencies import Input, Output, State
import dash_core_components as dcc

df = pd.read_csv(r'E:\Manaruchi\DIS\DIS\support_files\test.csv')

for c in df.columns:

    if(c[:7] == 'Unnamed'):
        df = df.drop([c],axis = 1)

app = dash.Dash(__name__, external_stylesheets=[dbc.themes.COSMO,
                                                "https://fonts.googleapis.com/css2?family=Lora&display=swap"])

app.layout = html.Div([
        
        dbc.Alert('Dash Data Table Demo for DIS',id = 'alertbox', color = 'success'),
    
        dcc.Loading(dash_table.DataTable(
            id='table',
            columns=[{"name": i, "id": i} for i in df.columns],
            data=df.to_dict('records'),
            page_size = 50,
            style_cell={
                'whiteSpace': 'normal',
                'height': 'auto', 'minWidth': '180px', 'width': '200px', 'maxWidth': '240px', 'textAlign': 'left'
            },
            style_table={'height': '500px', 'overflowY': 'auto', 'margin': '20px', 'width': '800px',},
            
            style_data = {'font-family': 'Lora', 'font-size': 'small'},
            style_header = {'font-family': 'Lora', 'font-size': 'small'},
            style_data_conditional=[
                {
                    'if': {'row_index': 'odd'},
                    'backgroundColor': 'rgb(248, 248, 248)'
                }
            ],

            editable=True,
            filter_action="native",
            sort_action="native",
            sort_mode="multi",
            selected_columns=[],
            selected_rows=[],
            page_action="native",
            page_current= 0,
            export_format='xlsx',
            export_headers='display',
            tooltip_data=[
                {
                    column: {'value': str(value), 'type': 'markdown'}
                    for column, value in row.items()
                } for row in df.to_dict('records')
            ],

        )),
    
    dbc.Button('Save', color = 'primary', id = 'savebutton'),
    
    dbc.Toast(
            "Changes to the database has been recorded.",
            id="modal",
            header="Changes Saved",
            is_open=False,
            dismissable=True,
            icon="primary", duration=4000,
            style={"position": "fixed", "top": 66, "right": 10, "width": 350, 
                   'background-color': 'black', 'color': 'white',
                   'border-radius': '10px'},
        ),
    
    

    ])


@app.callback(
    [Output("modal", "is_open"), 
     Output('table', 'columns'), 
     Output('table', 'data'),
     Output('table', 'tooltip_data')],
    [Input("savebutton", "n_clicks")
     ],
    [State('table', 'data'), State('table', 'columns'), State("modal", "is_open")],
)
def toggle_modal(n1, rows, columns, is_open):
    
    global df
    
    if n1:    
        
        export_df = pd.DataFrame(rows, columns=[c['name'] for c in columns])
        
        #print(df.compare(export_df))
        
        export_df.to_csv(r'E:\Manaruchi\DIS\DIS\support_files\test.csv')
        
        df = pd.read_csv(r'E:\Manaruchi\DIS\DIS\support_files\test.csv')
        
        for c in df.columns:
            
            if(c[:7] == 'Unnamed'):
                df = df.drop([c],axis = 1)
          
        df.to_csv(r'E:\Manaruchi\DIS\DIS\support_files\test.csv')
        
        tooltip_data=[
                {
                    column: {'value': str(value), 'type': 'markdown'}
                    for column, value in row.items()
                } for row in df.to_dict('records')
            ],

        
        
        return True, [{"name": i, "id": i} for i in df.columns], df.to_dict('records'), tooltip_data
    
    tooltip_data=[
                {
                    column: {'value': str(value), 'type': 'markdown'}
                    for column, value in row.items()
                } for row in df.to_dict('records')
            ],

        
    return False, [{"name": i, "id": i} for i in df.columns], df.to_dict('records'), tooltip_data


if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [01/Apr/2021 15:25:22] "GET /dataset HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Apr/2021 15:25:23] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Apr/2021 15:25:23] "GET /_favicon.ico?v=1.19.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Apr/2021 15:25:24] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Apr/2021 15:25:28] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
df
# Out:
#      Name of Industry            Name of allootte Unit Sector Plot Number  \
# 0       Bahadrabad_II         MANARUCHI SUPERMOHAPATRA      1        A-43
# 1       Bahadrabad_II        SABYASACHI SUPERMOHAPATRA      1        B-10
# 2       Bahadrabad_II          DIPTI PRAKASH MOHAPATRA      1        A-50
# 3       Bahadrabad_II                     ARATI BEHERA      1        B-47
# 4       Bahadrabad_II               MISS PRACHEE PATRA      1        B-54
# ...               ...                              ...    ...         ...
# 2806    IIE Pantnagar            Titan Company Limited      2         10B
# 2807    IIE Pantnagar  Tkt Plasto Moulders & Engineers      6          50
# 2808    IIE Pantnagar       Tonglit Autogistic Pvt Ltd  0ITBT          4A
# 2809    IIE Pantnagar            TVL Engineers Pvt Ltd      9           5
# 2810    IIE Pantnagar         Wiretech Auto Industries      6           7
#
#                 UID Area at the time of allotment in Sq. Mtr.  \
# 0          BD2_A-43                                       273
# 1          BD2_B-10                                     162.9
# 2          BD2_A-50                                       300
# 3          BD2_B-47                                     167.4
# 4          BD2_B-54                                     167.6
# ...             ...                                       ...
# 2806  Ptn_00002_10B                                       NaN
# 2807   Ptn_00006_50                                       NaN
# 2808   Ptn_0ITBT_4A                                       NaN
# 2809    Ptn_00009_5                                       NaN
# 2810    Ptn_00006_7                                       NaN
#
#      Area at the time of Possession in Sq. Mtr.  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2806                                        NaN
# 2807                                        NaN
# 2808                                        NaN
# 2809                                        NaN
# 2810                                        NaN
#
#      Constitution of Organization (Limited Nature of Project  \
# 0                               Proprietor             Other
# 1                               Proprietor   Export Oriented
# 2                               Proprietor   Export Oriented
# 3                               Proprietor   Export Oriented
# 4                               Proprietor   Export Oriented
# ...                                    ...               ...
# 2806                                   NaN               NaN
# 2807                                   NaN               NaN
# 2808                                   NaN               NaN
# 2809                                   NaN               NaN
# 2810                                   NaN               NaN
#
#          Proposed Product  ... Back-up electricity Diesel Generator  \
# 0     Residential Purpose  ...                 NaN              NaN
# 1                     NaN  ...                 NaN              NaN
# 2                     NaN  ...                 NaN              NaN
# 3                     NaN  ...                 NaN              NaN
# 4                     NaN  ...                 NaN              NaN
# ...                   ...  ...                 ...              ...
# 2806                  NaN  ...                 NaN              NaN
# 2807                  NaN  ...                 NaN              NaN
# 2808                  NaN  ...                 NaN              NaN
# 2809                  NaN  ...                 NaN              NaN
# 2810                  NaN  ...                 NaN              NaN
#
#      Energy Management Systems  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2806                       NaN
# 2807                       NaN
# 2808                       NaN
# 2809                       NaN
# 2810                       NaN
#
#      Renewable energy (Solar street lamp, solar panel, solar energy for common areas, Off site renewable energy)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
#
#      OH&S  Grievance management Help desk, Hotline, Complaint Box, Other)  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3      NaN                                                NaN
# 4      NaN                                                NaN
# ...    ...                                                ...
# 2806   NaN                                                NaN
# 2807   NaN                                                NaN
# 2808   NaN                                                NaN
# 2809   NaN                                                NaN
# 2810   NaN                                                NaN
#
#      Harassment Prevention and Redressal (Harassment redressal team, Sexual harassment redressal team, transport provision for women)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
#
#      Community Dialogue (Website, Media Release, News Bulletin, Social Media, Other)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
#
#      Community services such as drinking water supply, water harvesting, health camps etc.  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
#
#      Outreach activities: CSR Activities/ Clean up drives, health camp, public service activities etc.
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
#
# [2811 rows x 171 columns]
