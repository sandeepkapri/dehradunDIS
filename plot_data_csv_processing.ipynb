# %%
import pandas as pd

# %%
df = pd.read_csv('support_files/plot_details.csv')

# %%
df[df['UID'] == 'SPP_1_A'].dropna(axis='columns')
# Out:
#      Name of Industry           Name of allootte Unit Sector Plot Number  \
# 1843  SIDC Peepalsana  M/s Belwal Spinning Mills Ltd.      1           A
#
#           UID Area at the time of allotment in Sq. Mtr.  \
# 1843  SPP_1_A                                  104412.6
#
#      Area at the time of Possession in Sq. Mtr.  \
# 1843                                   104412.6
#
#      Constitution of Organization (Limited Nature of Project Proposed Product  \
# 1843                   Company Public Ltd.          Textiles         Spinning
#
#       ... Lease Deed Lease Deed Date Possession Possession Date Plot Status   \
# 1843  ...        Yes        7-Apr-86        Yes       16-Apr-86       Closed
#
#      Plot Status Date Occupancy Certificate Time Extension1  \
# 1843        16-Jul-12                    No              No
#
#      Time Extension Last Land Use
# 1843                  No     Plot
#
# [1 rows x 27 columns]

# %%
df
# Out:
#      Name of Industry            Name of allootte Unit Sector Plot Number  \
# 0       Bahadrabad_II                    BABITA JUNEJA      1        A-43
# 1       Bahadrabad_II                  BTIJENDER SINGH      1        B-10
# 2       Bahadrabad_II                  DR. N.C. TREHAN      1        A-50
# 3       Bahadrabad_II               DR. NARENDER KUMAR      1        B-47
# 4       Bahadrabad_II            DR. NEELAM SRIVASTAWA      1        B-54
# ...               ...                              ...    ...         ...
# 2806    IIE Pantnagar            Titan Company Limited      2         10B
# 2807    IIE Pantnagar  Tkt Plasto Moulders & Engineers      6          50
# 2808    IIE Pantnagar       Tonglit Autogistic Pvt Ltd  0ITBT          4A
# 2809    IIE Pantnagar            TVL Engineers Pvt Ltd      9           5
# 2810    IIE Pantnagar         Wiretech Auto Industries      6           7
#
#                 UID Area at the time of allotment in Sq. Mtr.  \
# ...
